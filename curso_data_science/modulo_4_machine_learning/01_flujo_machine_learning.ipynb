# %% [markdown]
# # Módulo 4: Fundamentos de Machine Learning
#
# Clasificaremos mediciones ambientales como normales o para revisar.

# %%
import pandas as pd
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    accuracy_score,
    classification_report,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Datos de práctica
#
# La etiqueta se construye para practicar el flujo. En un proyecto real debe definirse con criterios del dominio.

# %%
datos = pd.DataFrame({
    'temperatura': [18.5, 19.2, 25.4, 26.1, 8.9, 21.0, 22.4, 27.0, 17.5, 24.8, 10.0, 20.5],
    'humedad': [55, 58, 61, 59, 72, 64, 60, 57, 56, 62, 70, 65],
    'estado': ['normal', 'normal', 'revisar', 'revisar', 'revisar', 'normal', 'normal', 'revisar', 'normal', 'revisar', 'revisar', 'normal']
})
datos

# %%
# TODO: Define X con temperatura y humedad, y y con estado.
# TODO: Inspecciona el número de ejemplos por clase.

# %% [markdown]
# ## Separar y entrenar
#
# Reserva el 25% para prueba y conserva la proporción de clases.

# %%
# TODO: Usa train_test_split con random_state=42 y stratify=y.
# TODO: Entrena DecisionTreeClassifier(max_depth=3, random_state=42).
# TODO: Genera predicciones sobre X_prueba.

# %% [markdown]
# ## Evaluar e interpretar
#
# Calcula exactitud, muestra el reporte y dibuja la matriz de confusión. Escribe una conclusión y una limitación.

# %%
# TODO: Calcula accuracy_score.
# TODO: Usa classification_report.
# TODO: Visualiza ConfusionMatrixDisplay.

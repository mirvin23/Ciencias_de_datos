# %% [markdown]
# # Módulo 3: Visualización exploratoria
#
# Construiremos gráficos para comparar estaciones y explorar relaciones.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style='whitegrid')

# %% [markdown]
# ## Datos de práctica
#
# El conjunto es pequeño para que puedas inspeccionar también los puntos individuales.

# %%
datos = pd.DataFrame({
    'estacion': ['Norte', 'Norte', 'Sur', 'Sur', 'Centro', 'Centro', 'Este', 'Este'],
    'temperatura': [18.5, 19.2, 25.4, 26.1, 8.9, 21.0, 22.4, 23.0],
    'humedad': [55.0, 58.1, 61.2, 59.4, 72.4, 64.5, 60.3, 57.8]
})
datos

# %% [markdown]
# ## 1. Comparar promedios
#
# ¿Qué estación tiene la temperatura promedio más alta?

# %%
# TODO: Calcula promedios por estación.
# TODO: Crea un gráfico de barras con título y unidades.

# %% [markdown]
# ## 2. Comparar distribuciones
#
# Usa un boxplot para observar centro y dispersión.

# %%
# TODO: Crea un boxplot de temperatura por estación.
# TODO: Describe una diferencia visible.

# %% [markdown]
# ## 3. Explorar relaciones
#
# Relaciona temperatura y humedad sin confundir asociación con causalidad.

# %%
# TODO: Crea un scatterplot con hue='estacion'.
# TODO: Calcula la correlación entre temperatura y humedad.

# %% [markdown]
# ## Reflexión
#
# Escribe una observación, una medición que la respalde y una limitación del análisis.

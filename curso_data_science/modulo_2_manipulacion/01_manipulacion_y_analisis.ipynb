# %% [markdown]
# # Módulo 2: Manipulación y análisis de datos
#
# Usaremos NumPy y Pandas para analizar mediciones ambientales.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Crear datos de práctica
#
# Cada fila representa una medición de una estación ambiental.

# %%
datos = pd.DataFrame({
    'estacion': ['Norte', 'Sur', 'Norte', 'Centro', 'Sur', 'Centro', 'Norte', 'Sur'],
    'temperatura': [18.5, 25.4, 19.2, 8.9, 26.1, 21.0, np.nan, 22.4],
    'humedad': [55.0, 61.2, 58.1, 72.4, np.nan, 64.5, 59.0, 60.3]
})
datos

# %%
# TODO: Inspecciona forma, columnas, tipos y valores faltantes.

# %% [markdown]
# ## 2. Transformar y filtrar
#
# Marca como anómala una temperatura menor que 10 o mayor que 24 grados Celsius.

# %%
# TODO: Crea la columna 'fuera_de_rango'.
# TODO: Crea una tabla con las mediciones anómalas.

# %% [markdown]
# ## 3. Resumir por estación
#
# Calcula cantidad de mediciones, temperatura promedio y número de anomalías por estación.

# %%
# TODO: Construye el DataFrame 'resumen'.
# TODO: Comprueba que el resumen tiene una fila por estación.

# %% [markdown]
# ## 4. Reto de interpretación
#
# Añade el promedio de humedad y una columna 'recomendacion': usa 'revisar' si la estación tiene al menos una anomalía.

# %%
# TODO: Extiende el resumen y escribe una conclusión breve.

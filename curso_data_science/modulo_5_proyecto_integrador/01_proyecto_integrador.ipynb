# %% [markdown]
# # Proyecto integrador
#
# Analiza mediciones ambientales y construye una recomendación reproducible.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    accuracy_score,
    classification_report,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

sns.set_theme(style='whitegrid')

# %% [markdown]
# ## 1. Cargar e inspeccionar
#
# Usa el dataset central y registra forma, tipos, faltantes y distribución del objetivo.

# %%
# TODO: Carga ../datasets/mediciones_integrador.csv.
# TODO: Inspecciona datos.info(), duplicados, faltantes y value_counts().

# %% [markdown]
# ## 2. Análisis exploratorio
#
# Calcula el resumen por estación y la proporción de alertas.

# %%
# TODO: Construye resumen con mediciones, promedios y alertas.
# TODO: Calcula proporcion_alertas.

# %% [markdown]
# ## 3. Visualizar
#
# Crea tres gráficos y escribe debajo una observación verificable para cada uno.

# %%
# TODO: Barras de proporcion_alertas por estacion.
# TODO: Boxplot de temperatura por estado.
# TODO: Scatterplot de temperatura y humedad con hue='estado'.

# %% [markdown]
# ## 4. Modelo y evaluación
#
# Entrena un árbol de decisión, compara dos profundidades y registra métricas y errores.

# %%
# TODO: Separa X e y y divide train/test con random_state=42.
# TODO: Entrena max_depth=3 y calcula accuracy y classification_report.
# TODO: Muestra la matriz de confusión.
# TODO: Compara con otra profundidad.

# %% [markdown]
# ## 5. Conclusión
#
# Escribe: evidencia observada, interpretación prudente, recomendación y una limitación.
